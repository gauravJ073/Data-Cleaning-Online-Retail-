# %% [markdown]
# #### Information
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# #### Features Descriptions
# 1. **InvoiceNo**: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# 2. **StockCode**: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.
# 3. **Description**: Product (item) name. Nominal.
# 4. **Quantity**: The quantities of each product (item) per transaction. Numeric.
# 5. **InvoiceDate**: Invice Date and time. Numeric, the day and time when each transaction was generated.
# 6. **UnitPrice**: Unit price. Numeric, Product price per unit in sterling.
# 7. **CustomerID**: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.
# 8. **Country**: Country name. Nominal, the name of the country where each customer resides.

# %% [markdown]
# ## Preparing Environment

# %%
import pandas as pd 
import numpy as np
import datetime as dt 
from IPython.display import display


pd.set_option('display.max_columns', None)

data_uncleaned=pd.read_excel("../Data/Online Retail.xlsx")
data=data_uncleaned.copy()

# %% [markdown]
# ## Exploring Data

# %% [markdown]
# ### General Exploration

# %%
#exploring the shape of dataset and viewing first 10 rows of dataset

print("Shape of data: ", data.shape,"\n")
display(data.head(10))
# Out:
# Shape of data:  (541909, 8)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
# Checking data type of each feature and presence of any null values
display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# None

# %% [markdown]
# Columns 'Description' and 'CustomerID' contain null values
#
# Also, column "CustomerID" is detected as 'float64' data type when it should actually be object type

# %%
# checking the number of null values
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Checking unique values
data.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %% [markdown]
# According to data description, 'StockCode' is the code assigned to a unique product and 'Description' is the name of the product. So, in theory, number of unique values in 'StockCode' and 'Description' should be the same. But there seem to be more unique values in 'Description' as compared to 'StockCode' which could be the result of some kind of error or mistake that is worth investigating.

# %%
# Exploring numerical columns in dataset
display(data.describe())
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# **NOTE**: Ignore 'CustomerID' column because it is wrongly detected as float64 instead of object
#
# We can observe that 'min' minimum value for 'Quantity' and 'UnitPrice' is a negative number. This could be the result of canceled or return orders but regardless it is worth investigating further.

# %%
#Checking for dubplicates
display(data.duplicated().sum())
# Out:
# 5268

# %% [markdown]
# We can clearly observe that there are a lot of duplicate values in the dataset and these are needed to be removed in order to clean the data to aensure they don't affect the analysis of the data.

# %% [markdown]
# ### Exploring 'Quantity' column

# %%
# Exploring negative quantity
display(data[data['Quantity']<0].head(10))
display(data[data['Quantity']<0].tail(10))
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 141   C536379         D                           Discount        -1
# 154   C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
# 939   C536506     22960           JAM MAKING SET WITH JARS        -6
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 238 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 239 2010-12-01 10:24:00       3.45     17548.0  United Kingdom
# 240 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 241 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 939 2010-12-01 12:38:00       4.25     17897.0  United Kingdom
#        InvoiceNo StockCode                       Description  Quantity  \
# 540141   C581468     21314     SMALL GLASS HEART TRINKET POT       -10
# 540142   C581468     22098         BOUDOIR SQUARE TISSUE BOX       -12
# 540176   C581470     23084                RABBIT NIGHT LIGHT        -4
# 540422   C581484     23843       PAPER CRAFT , LITTLE BIRDIE    -80995
# 540448   C581490     22178   VICTORIAN GLASS HANGING T-LIGHT       -12
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540141 2011-12-08 19:26:00       2.10     13599.0  United Kingdom
# 540142 2011-12-08 19:26:00       0.39     13599.0  United Kingdom
# 540176 2011-12-08 19:28:00       2.08     17924.0  United Kingdom
# 540422 2011-12-09 09:27:00       2.08     16446.0  United Kingdom
# 540448 2011-12-09 09:57:00       1.95     14397.0  United Kingdom
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom

# %%
print("Number of entries of canceled orders: ",len(data[data['InvoiceNo'].str.startswith('C')==True].index))
print("Number of entries of orders with negative quantity: ",len(data[data['Quantity']<=0]))
# Out:
# Number of entries of canceled orders:  9288
# Number of entries of orders with negative quantity:  10624

# %% [markdown]
# As expected, most of the negative values in 'Quantity' arise as a result of cancelled orders or discounts etc. It might be worth keeping a seperate record of all these orders to study cancelled orders or to understand total profit and loss. However, there seem to be more entries with negative quantity than cancelled orders

# %%
display(data[(data['Quantity']<0) & (data['InvoiceNo'].str.contains('C', na=False)==False)].head(10))

display(data[(data['Quantity']<0) & (data['InvoiceNo'].str.contains('C', na=False)==False)].tail(10))
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 2406    536589     21777         NaN       -10 2010-12-01 16:50:00        0.0
# 4347    536764    84952C         NaN       -38 2010-12-02 14:42:00        0.0
# 7188    536996     22712         NaN       -20 2010-12-03 15:30:00        0.0
# 7189    536997     22028         NaN       -20 2010-12-03 15:30:00        0.0
# 7190    536998     85067         NaN        -6 2010-12-03 15:30:00        0.0
# 7192    537000     21414         NaN       -22 2010-12-03 15:32:00        0.0
# 7193    537001     21653         NaN        -6 2010-12-03 15:33:00        0.0
# 7195    537003     85126         NaN        -2 2010-12-03 15:33:00        0.0
# 7196    537004     21814         NaN       -30 2010-12-03 15:34:00        0.0
# 7197    537005     21692         NaN       -70 2010-12-03 15:35:00        0.0
#
#       CustomerID         Country
# 2406         NaN  United Kingdom
# 4347         NaN  United Kingdom
# 7188         NaN  United Kingdom
# 7189         NaN  United Kingdom
# 7190         NaN  United Kingdom
# 7192         NaN  United Kingdom
# 7193         NaN  United Kingdom
# 7195         NaN  United Kingdom
# 7196         NaN  United Kingdom
# 7197         NaN  United Kingdom
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 535327    581204     85104  ????damages????      -355 2011-12-07 18:32:00
# 535328    581205     20893          damages       -55 2011-12-07 18:32:00
# 535329    581206     21693         mixed up       -87 2011-12-07 18:34:00
# 535330    581207     21688         mixed up      -337 2011-12-07 18:34:00
# 535331    581208    72801C            check       -10 2011-12-07 18:35:00
# 535333    581210     23395            check       -26 2011-12-07 18:36:00
# 535335    581212     22578             lost     -1050 2011-12-07 18:38:00
# 535336    581213     22576            check       -30 2011-12-07 18:38:00
# 536908    581226     23090          missing      -338 2011-12-08 09:56:00
# 538919    581422     23169          smashed      -235 2011-12-08 15:24:00
#
#         UnitPrice  CustomerID         Country
# 535327        0.0         NaN  United Kingdom
# 535328        0.0         NaN  United Kingdom
# 535329        0.0         NaN  United Kingdom
# 535330        0.0         NaN  United Kingdom
# 535331        0.0         NaN  United Kingdom
# 535333        0.0         NaN  United Kingdom
# 535335        0.0         NaN  United Kingdom
# 535336        0.0         NaN  United Kingdom
# 536908        0.0         NaN  United Kingdom
# 538919        0.0         NaN  United Kingdom

# %% [markdown]
# On checking the orders that were not cancelled but still had negative values for 'Quantity', we can observe that they were lost, mixed up, damaged etc. In other words, they caused a loss to the organisation/company.
#
# It might be worth keeping a seperate record of all such orders since it might help to analyse profit and loss based on these transactions

# %% [markdown]
# ### Exploring 'UnitPrice' Column

# %%
# Exploring negative unit proce
display(data[data['UnitPrice']<0].head())
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# The negative unit price seem to be debt payments that occured with stock code = 'B'

# %%
display(data[data['StockCode']=='B'].head())
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# We can observe that there was another transaction with same stock code and it was the same amount but it was not negative. This could be typing error

# %% [markdown]
# ### Exploring 'Description' Column

# %%
display(len(data['Description'].unique()))

display(data['Description'].unique())
# Out:
# 4224
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %% [markdown]
# We can notice that there are 4224 unique values in Desscription column but as we noticed before, some of these values don't contain product name, but rather contain additional information like if the order went missing , was damaged , wet etc.
#
# The true product names are all stored in upper case and other information is either stored as title case or lower case

# %%
#creating a new dataframe to hold the list of all different unique values in 'Description' column
desc_unique=pd.DataFrame(data['Description'].unique().astype(str), columns=['Desc_unique'])

# %%
#viewing all uppercase descrption (majority are product names)
display(desc_unique[desc_unique['Desc_unique'].str.isupper()==True])

#viewing all lowercase description
display(desc_unique[desc_unique['Desc_unique'].str.islower()==True])

#viewing all titlecase description
display(desc_unique[desc_unique['Desc_unique'].str.istitle()==True])

#viewing all other types of case in description
display(desc_unique[(desc_unique['Desc_unique'].str.isupper()==False)&(desc_unique['Desc_unique'].str.islower()==False)&(desc_unique['Desc_unique'].str.istitle()==False)])
# Out:
#                               Desc_unique
# 0      WHITE HANGING HEART T-LIGHT HOLDER
# 1                     WHITE METAL LANTERN
# 2          CREAM CUPID HEARTS COAT HANGER
# 3     KNITTED UNION FLAG HOT WATER BOTTLE
# 4          RED WOOLLY HOTTIE WHITE HEART.
# ...                                   ...
# 4210       SET 10 CARDS SNOWY ROBIN 17099
# 4212  SET 10 CARDS SWIRLY XMAS TREE 17104
# 4216            LETTER "U" BLING KEY RING
# 4222   CREAM HANGING HEART T-LIGHT HOLDER
# 4223          PAPER CRAFT , LITTLE BIRDIE
#
# [4018 rows x 1 columns]
#           Desc_unique
# 395               nan
# 1740           amazon
# 2155            check
# 2157          damages
# 2394           faulty
# ...               ...
# 4217              wet
# 4218        wet boxes
# 4219  ????damages????
# 4220         mixed up
# 4221             lost
#
# [128 rows x 1 columns]
#                               Desc_unique
# 111                              Discount
# 1108                               Manual
# 1537                         Bank Charges
# 2373                *Boombox Ipod Classic
# 2722   Dotcomgiftshop Gift Voucher £40.00
# 2727                                Found
# 2754   Dotcomgiftshop Gift Voucher £50.00
# 2781   Dotcomgiftshop Gift Voucher £30.00
# 2782   Dotcomgiftshop Gift Voucher £20.00
# 2910                               Dotcom
# 3106                           Adjustment
# 3107   Dotcomgiftshop Gift Voucher £10.00
# 3201                              Damaged
# 3272                              Display
# 3275                              Missing
# 3458                    Next Day Carriage
# 3594                         Show Samples
# 3723  Dotcomgiftshop Gift Voucher £100.00
# 3850                              Crushed
# 3879                               Amazon
# 3920                              Dagamed
# 4064                High Resolution Image
# 4093                    Amazon Adjustment
# 4106                            Breakages
# 4119                              Damages
# 4179                           John Lewis
#                               Desc_unique
# 326               BAG 500g SWIRLY MARBLES
# 550          POLYESTER FILLER PAD 45x45cm
# 1037              BAG 125g SWIRLY MARBLES
# 1038              BAG 250g SWIRLY MARBLES
# 1052         POLYESTER FILLER PAD 45x30cm
# 1053         POLYESTER FILLER PAD 40x40cm
# 1061       FRENCH BLUE METAL DOOR SIGN No
# 1187        Dr. Jam's Arouzer Stress Ball
# 1367   3 TRADITIONAl BISCUIT CUTTERS  SET
# 1582        NUMBER TILE COTTAGE GARDEN No
# 1746       FOLK ART GREETING CARD,pack/12
# 1822                                    ?
# 2089  ESSENTIAL BALM 3.5g TIN IN ENVELOPE
# 2139       POLYESTER FILLER PAD 65CMx65CM
# 2165           Dad's Cab Electronic Meter
# 2233         NUMBER TILE VINTAGE FONT No
# 2419                         Dotcom sales
# 2672              *USB Office Mirror Ball
# 2681       POLYESTER FILLER PAD 30CMx30CM
# 2909                           Given away
# 3114                           Dotcom set
# 3117                     Amazon sold sets
# 3126                         Thrown away.
# 3192                   Dotcom sold in 6's
# 3214     mystery! Only ever imported 1800
# 3333           damages/credits from ASOS.
# 3343         POLYESTER FILLER PAD 60x40cm
# 3361      Not rcvd in 10/11/2010 delivery
# 3386                    Thrown away-rusty
# 3391      FLOWERS HANDBAG blue and orange
# 3453  incorrectly credited C550456 see 47
# 3484                        Water damaged
# 3556         Printing smudges/thrown away
# 3691         THE KING GIFT BAG 25x24x12cm
# 3715                      Damages/samples
# 3726                  Sold as 1 on dotcom
# 3762                      Adjust bad debt
# 3790                      CRUK Commission
# 3870                                   ??
# 3883                    OOPS ! adjustment
# 3884                       Found in w/hse
# 3985  Lighthouse Trading zero invc incorr
# 3986               Incorrect stock entry.
# 4039               Wet pallet-thrown away
# 4040                  Had been put aside.
# 4062                           Sale error
# 4110                      Marked as 23343
# 4111                                20713
# 4117                      Found by jackie
# 4128               Unsaleable, destroyed.
# 4152      Wrongly mrked had 85123a in box
# 4215                                  ???

# %% [markdown]
# We can observe that there are a lot of non-product name entries in the 'Description' column and there also seem to be some typing errors in it as well.

# %% [markdown]
# ### Exploring 'StockCode' Column

# %%
#total number of different products based on StockCode
display(len(data['StockCode'].unique()))

display(data['StockCode'].unique())
# Out:
# 4070
# array(['85123A', 71053, '84406B', ..., '90214U', '47591b', 23843],
#       dtype=object)

# %% [markdown]
# We can observe that there are a total of 4070 unique entries in 'StockCode' column and most of them are either purely numeric or purely alpha-numeric values

# %%
#creating a dataframe of all unique values in 'StockCode' column
stockcode_unique=pd.DataFrame(data['StockCode'].unique().astype(str), columns=['StockCode_unique'])

# %%
#viewing all purely numeric stock codes
display(stockcode_unique[stockcode_unique['StockCode_unique'].str.isnumeric()==True])

#viewing all purely alpha numeric stock codes
display(stockcode_unique[(stockcode_unique['StockCode_unique'].str.isalnum()==True)&(stockcode_unique['StockCode_unique'].str.isalpha()==False)&(stockcode_unique['StockCode_unique'].str.isnumeric()==False)])

#viewing all purely alphabetical stock codes
display(stockcode_unique[stockcode_unique['StockCode_unique'].str.isalpha()==True])

#viewing all other stock codes
display(stockcode_unique[(stockcode_unique['StockCode_unique'].str.isalnum()==False)&(stockcode_unique['StockCode_unique'].str.isalpha()==False)&(stockcode_unique['StockCode_unique'].str.isnumeric()==False)])
# Out:
#      StockCode_unique
# 1               71053
# 5               22752
# 6               21730
# 7               22633
# 8               22632
# ...               ...
# 4062            23562
# 4063            23561
# 4064            23609
# 4066            23617
# 4069            23843
#
# [2946 rows x 1 columns]
#      StockCode_unique
# 0              85123A
# 2              84406B
# 3              84029G
# 4              84029E
# 55             82494L
# ...               ...
# 4055           84971l
# 4056           85034b
# 4065           85179a
# 4067           90214U
# 4068           47591b
#
# [1106 rows x 1 columns]
#      StockCode_unique
# 45               POST
# 111                 D
# 952               DOT
# 1115                M
# 2242                S
# 2245        AMAZONFEE
# 2791                m
# 3078         DCGSSBOY
# 3079        DCGSSGIRL
# 3328             PADS
# 3753                B
# 3772             CRUK
#      StockCode_unique
# 1542     BANK CHARGES
# 2774     gift_0001_40
# 2815     gift_0001_50
# 2842     gift_0001_30
# 2843     gift_0001_20
# 3197     gift_0001_10

# %% [markdown]
# We can observe that there are a lot of entries in 'StockCode' which indicates that there is data about non-sales transactions. This means we need to take care of it during the cleaning phase and remove it since the primary objective of analysis on this data is going to be to analyse the sales of different projects and purcheses made my different customers. Hence, any non-sales data is irrelevant to the project.

# %% [markdown]
# ### Exploring 'Country' column

# %%
#checking 'Country' column to look for any errors
data['Country'].value_counts().sort_index()
# Out:
# Australia                 1259
# Austria                    401
# Bahrain                     19
# Belgium                   2069
# Brazil                      32
# Canada                     151
# Channel Islands            758
# Cyprus                     622
# Czech Republic              30
# Denmark                    389
# EIRE                      8196
# European Community          61
# Finland                    695
# France                    8557
# Germany                   9495
# Greece                     146
# Hong Kong                  288
# Iceland                    182
# Israel                     297
# Italy                      803
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      127
# Netherlands               2371
# Norway                    1086
# Poland                     341
# Portugal                  1519
# RSA                         58
# Saudi Arabia                10
# Singapore                  229
# Spain                     2533
# Sweden                     462
# Switzerland               2002
# USA                        291
# United Arab Emirates        68
# United Kingdom          495478
# Unspecified                446
# Name: Country, dtype: int64

# %% [markdown]
# There don't seem to be any errors in the values of 'Country' column. However, there seem to be a value named 'unspecified'.This means that there are some rows have missing values for 'Country' column and instead of NULL they store the value 'Unspecified'

# %% [markdown]
# ## Data Cleaning
#
# Now we have explored the data and are familiar with it, we can now start cleaning it based on what we have learned from exploring it

# %% [markdown]
# For cleaning the data we need to do the following things:
# 1. **fixing Data type**: We observed during data exploring that the column 'CustomerID' is of Float64 data type when it should actually be just string type and there are other columsn that are of datatype 'Object' and are neede to be converted into string
#
# 2. **Delete Duplicate Data**: The duplicate rows in the dataset needs to be removed to clean the dataset for analysis. We can do this using duplicate() function of pandas library for DataFrame objects.
#
# 3. **Remove non-sales transactions data**: From exploring data we observed that a lot of data in the dataset is non-sales related transactional data, for example - amazon fees, bank charges, gifts, etc. All this data is irrelevant because data needs to be cleaned for analysis of sales of different products. One way to doing this would be to use StockCodes column. The StockCodes column mostly consists of product id of different products, and these product ids are either purely numeric values or are alpha numeric values and they are of length 5 or more, all other enteries are for non-sales transactions.
#
# 4. **Make a new dataset for data of profit and non profit transactions**: While exploring 'Description' column, we observed a lot of irregularities and missing values in the 'Description' column. We could also observe that in almost all of these cases, the 'Quantity' column had a negative value meaning these were a loss for the company. We will make a seperate dataset for such data and clean it as well and save it seperately since it might be needed for evaluation of losses due to different reasons.
#
# 5. **Dealing with missing values**: During exploration, it was observed that there were a lot of missing values for columns 'Descrption', 'CustomerID' and 'Country'(they were marked as "unspecified" in country column).
#
#      * **For 'Description'**: For this column, if there was any cancelled order or any non cancelation order with a positive 'Quantity' value with missing descrption then it can be corrected by putting the value of any non null description with same stock code. For non cancelation orders with negative 'Quantity' value with missing description, they will be marked as "damaged" and if their description value is only "?" or "??" or "???", they will be marked as "missing"
#
#      * **For 'CustomerID'**: For this column, almost all missing values are for non-sales transacations and if they are missing in sales transaction data, those rows of data will not be removed since it might affect the analysis of the data
#
#      * **For 'Country'**: Rows with "unspecified" values for this columns will not be removed as well but shall be taken note of during data analysis which will not be the part of this project.

# %% [markdown]
# ### 1. Fixing Data types
#
# Now we will change the data types of the columns to make sure they are of correct data type. In order to achieve that we will convert all columns with datatype as "object" to string because columns with object datatype can hold strings, floats, integers and any other datatype values in them and we need to make sure they are all of same datatype, that is string datatype, to keep the dataset consistent.

# %%
#changing data types to string
data['InvoiceNo']=data['InvoiceNo'].astype(str) 

data['StockCode']=data['StockCode'].astype(str)

data['Description']=data['Description'].astype(str)

data['CustomerID']=data['CustomerID'].astype(str)

data['Country']=data['Country'].astype(str)

# %% [markdown]
# ### 2. Deleting Dubplicates

# %% [markdown]
# We will delete dublicate values from the dataset using duplicate() function.

# %%
data = data[~data.duplicated()]

# %% [markdown]
# ### 3. Removing non-sales Transactional data

# %% [markdown]
# We will create a seperate dataset to store all sales related transactional data. We will do this by using only numeric and alpha numeric StockCode values since all other StockCode values are for non sales transactions data.

# %%
#creating a list of purely numeric and alpha-Numeric stockcodes
alphaNum_stockcode=sum(stockcode_unique[(stockcode_unique['StockCode_unique'].str.isalnum()==True)&(stockcode_unique['StockCode_unique'].str.isalpha()==False)&(stockcode_unique['StockCode_unique'].str.len()>=4)].values.tolist(), [])

#creating a new dataset for sales data
data_sales=pd.DataFrame(columns=data.columns.tolist())

#iterating through each stock code and adding it to the new dataset for sales data
for x in alphaNum_stockcode:
    data_sales=pd.concat([data_sales, data[data['StockCode']==x]], axis=0)

# %%
display(data_sales)
# Out:
#        InvoiceNo StockCode                          Description Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 49        536373    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 66        536375    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 220       536390    85123A   WHITE HANGING HEART T-LIGHT HOLDER       64
# 262       536394    85123A   WHITE HANGING HEART T-LIGHT HOLDER       32
# ...          ...       ...                                  ...      ...
# 512588    579512     23617  SET 10 CARDS SWIRLY XMAS TREE 17104        2
# 527065    580691    90214U            LETTER "U" BLING KEY RING       12
# 537224    581238    47591b             SCOTTIES CHILDRENS APRON        1
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE    80995
# 540422   C581484     23843          PAPER CRAFT , LITTLE BIRDIE   -80995
#
#                 InvoiceDate UnitPrice CustomerID         Country
# 0       2010-12-01 08:26:00      2.55    17850.0  United Kingdom
# 49      2010-12-01 09:02:00      2.55    17850.0  United Kingdom
# 66      2010-12-01 09:32:00      2.55    17850.0  United Kingdom
# 220     2010-12-01 10:19:00      2.55    17511.0  United Kingdom
# 262     2010-12-01 10:39:00      2.55    13408.0  United Kingdom
# ...                     ...       ...        ...             ...
# 512588  2011-11-29 16:47:00      2.91        nan  United Kingdom
# 527065  2011-12-05 15:48:00      0.29    13790.0  United Kingdom
# 537224  2011-12-08 10:53:00      4.13        nan  United Kingdom
# 540421  2011-12-09 09:15:00      2.08    16446.0  United Kingdom
# 540422  2011-12-09 09:27:00      2.08    16446.0  United Kingdom
#
# [533673 rows x 8 columns]

# %% [markdown]
# ### 4. Making a new dataset for data of profit and non profit transactions

# %% [markdown]
# We will create seperate datasets for profit adn non profit sales data. We will do this using the value sin "Quantity" column. All negative values in Quantity column indicates the non-profit transactions and all positive values indicates the profit data.

# %%
#creating a new dataset for profitable sales data
data_sales_profit=data_sales[data_sales['Quantity']>0]

display(data_sales_profit)
# Out:
#        InvoiceNo StockCode                          Description Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 49        536373    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 66        536375    85123A   WHITE HANGING HEART T-LIGHT HOLDER        6
# 220       536390    85123A   WHITE HANGING HEART T-LIGHT HOLDER       64
# 262       536394    85123A   WHITE HANGING HEART T-LIGHT HOLDER       32
# ...          ...       ...                                  ...      ...
# 509369    579297    85179a              GREEN BITTY LIGHT CHAIN        1
# 512588    579512     23617  SET 10 CARDS SWIRLY XMAS TREE 17104        2
# 527065    580691    90214U            LETTER "U" BLING KEY RING       12
# 537224    581238    47591b             SCOTTIES CHILDRENS APRON        1
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE    80995
#
#                 InvoiceDate UnitPrice CustomerID         Country
# 0       2010-12-01 08:26:00      2.55    17850.0  United Kingdom
# 49      2010-12-01 09:02:00      2.55    17850.0  United Kingdom
# 66      2010-12-01 09:32:00      2.55    17850.0  United Kingdom
# 220     2010-12-01 10:19:00      2.55    17511.0  United Kingdom
# 262     2010-12-01 10:39:00      2.55    13408.0  United Kingdom
# ...                     ...       ...        ...             ...
# 509369  2011-11-29 11:23:00      2.46        nan  United Kingdom
# 512588  2011-11-29 16:47:00      2.91        nan  United Kingdom
# 527065  2011-12-05 15:48:00      0.29    13790.0  United Kingdom
# 537224  2011-12-08 10:53:00      4.13        nan  United Kingdom
# 540421  2011-12-09 09:15:00      2.08    16446.0  United Kingdom
#
# [523669 rows x 8 columns]

# %%
#creating new dataset for non-profit sales data.
data_sales_nonProfit=data_sales[data_sales['Quantity']<0]

display(data_sales_nonProfit)
# Out:
#        InvoiceNo StockCode                         Description Quantity  \
# 14529    C537602    85123A  WHITE HANGING HEART T-LIGHT HOLDER       -1
# 24911    C538350    85123A  WHITE HANGING HEART T-LIGHT HOLDER       -1
# 29949    C538834    85123A  WHITE HANGING HEART T-LIGHT HOLDER       -1
# 34292    C539329    85123A  WHITE HANGING HEART T-LIGHT HOLDER     -500
# 38444    C539576    85123A  WHITE HANGING HEART T-LIGHT HOLDER      -24
# ...          ...       ...                                 ...      ...
# 431382    573597     79341              Unsaleable, destroyed.     -905
# 431383    573598    79342B              Unsaleable, destroyed.    -1128
# 515699   C579783     23597          PAPER BUNTING PAISLEY PARK       -6
# 516138   C579869     23428      IVORY RETRO KITCHEN WALL CLOCK       -2
# 540422   C581484     23843         PAPER CRAFT , LITTLE BIRDIE   -80995
#
#                 InvoiceDate UnitPrice CustomerID         Country
# 14529   2010-12-07 12:45:00      2.55    17511.0  United Kingdom
# 24911   2010-12-10 15:01:00      2.55    13798.0  United Kingdom
# 29949   2010-12-14 13:06:00      2.95    14415.0  United Kingdom
# 34292   2010-12-17 09:37:00      2.55    16013.0  United Kingdom
# 38444   2010-12-20 12:25:00      2.95    14911.0            EIRE
# ...                     ...       ...        ...             ...
# 431382  2011-10-31 15:18:00       0.0        nan  United Kingdom
# 431383  2011-10-31 15:18:00       0.0        nan  United Kingdom
# 515699  2011-11-30 15:21:00      2.95    17727.0  United Kingdom
# 516138  2011-11-30 16:44:00      8.15    14189.0  United Kingdom
# 540422  2011-12-09 09:27:00      2.08    16446.0  United Kingdom
#
# [10004 rows x 8 columns]

# %% [markdown]
# ### 5. Missing values in 'Description' Column

# %% [markdown]
# We saw earlier that there are missing values which are marked as either NULL of marked as "?", "??" or "???" in 'Description' column but these can be corrected by using values from other entries with same stock code.
#
# **NOTE**: We are not removing any rows which contain null values because that wil have a huge impact on the final analysis of the data hence we will keep all rows containaing null or missing values for any column.

# %%
print("NULL values in profit sales data: ",data_sales_profit[data_sales_profit['Description']=='nan'].shape[0])
print("NULL values in non-profit sales data: ",data_sales_nonProfit[data_sales_nonProfit['Description']=='nan'].shape[0])
# Out:
# NULL values in profit sales data:  584
# NULL values in non-profit sales data:  862

# %%
print("Missing values in profit sales data: ")
display(data_sales_profit[data_sales_profit['Description']=='?'])
# Out:
# Missing values in profit sales data:
#        InvoiceNo StockCode Description Quantity          InvoiceDate  \
# 220843    556231    85123A           ?     4000  2011-06-09 15:04:00
# 38261     539494     21479           ?      752  2010-12-20 10:36:00
# 282882    561665     22171           ?      142  2011-07-28 16:55:00
# 115807    546139     84988           ?     3000  2011-03-09 16:35:00
# 421093    572920    72803A           ?      117  2011-10-26 16:52:00
# 323315    565288     23135           ?      101  2011-09-02 11:43:00
#
#        UnitPrice CustomerID         Country
# 220843       0.0        nan  United Kingdom
# 38261        0.0        nan  United Kingdom
# 282882       0.0        nan  United Kingdom
# 115807       0.0        nan  United Kingdom
# 421093       0.0        nan  United Kingdom
# 323315       0.0        nan  United Kingdom

# %%
print("Missing values in non-profit sales data: ")
display(data_sales_nonProfit[data_sales_nonProfit['Description']=='?'])
display(data_sales_nonProfit[data_sales_nonProfit['Description']=='??'])
display(data_sales_nonProfit[data_sales_nonProfit['Description']=='???'])
# Out:
# Missing values in non-profit sales data:
#        InvoiceNo StockCode Description Quantity          InvoiceDate  \
# 128467    547339    84406B           ?     -450  2011-03-22 11:51:00
# 50806     540558     21258           ?      -29  2011-01-10 10:04:00
# 229381       0.0        nan  United Kingdom
# 352827       0.0        nan  United Kingdom
# 78235        0.0        nan  United Kingdom
# 229380       0.0        nan  United Kingdom
# 21518        0.0        nan  United Kingdom
# 243390       0.0        nan  United Kingdom
# 360738       0.0        nan  United Kingdom
# 205953       0.0        nan  United Kingdom
# 115811       0.0        nan  United Kingdom
# 323462       0.0        nan  United Kingdom
# 51673        0.0        nan  United Kingdom
# 350350       0.0        nan  United Kingdom
# 116406       0.0        nan  United Kingdom
# 263184       0.0        nan  United Kingdom
# 323390       0.0        nan  United Kingdom
# 397225       0.0        nan  United Kingdom
# 221959       0.0        nan  United Kingdom
# 7313         0.0        nan  United Kingdom
# 290580       0.0        nan  United Kingdom
# 255901       0.0        nan  United Kingdom
# 254446       0.0        nan  United Kingdom
# 292269       0.0        nan  United Kingdom
# 397026       0.0        nan  United Kingdom
# 381307       0.0        nan  United Kingdom
#        InvoiceNo StockCode Description Quantity          InvoiceDate  \
# 337534    566449     20856          ??     -140  2011-09-12 16:07:00
# 418840    572749     22572          ??     -335  2011-10-25 16:52:00
# 340683    566712     22030          ??     -635  2011-09-14 12:04:00
# 455407    575615     82582          ??     -130  2011-11-10 12:51:00
# 390852    570599    84596G          ??     -365  2011-10-11 12:00:00
# 418130    572702    37479P          ??     -184  2011-10-25 14:33:00
# 381687    569886     90191          ??      -60  2011-10-06 15:24:00
#
#        UnitPrice CustomerID         Country
# 337534       0.0        nan  United Kingdom
# 418840       0.0        nan  United Kingdom
# 340683       0.0        nan  United Kingdom
# 455407       0.0        nan  United Kingdom
# 390852       0.0        nan  United Kingdom
# 418130       0.0        nan  United Kingdom
# 381687       0.0        nan  United Kingdom
#        InvoiceNo StockCode Description Quantity          InvoiceDate  \
# 524370    580547     21201         ???     -390  2011-12-05 09:29:00
#
#        UnitPrice CustomerID         Country
# 524370       0.0        nan  United Kingdom

# %% [markdown]
# We can note that there are 584 NULL values in the profit dataset and 862 NULL values in the non-profit dataset.
#
# Moreover the missing values are marked as "?" or "??" or "???" in both the datasets.
#
#
# * **For profit sales data**, we will replace NULL and "?" with product names by matching the stock codes.
# * **For non-profit sales data**, we will replace NULL "?", "??", "???" with the product names by matching the Stockcodes if the order was for cancelled orders (marked with a 'C' in the invoice number) and for others, we will replace them with "missing".

# %%
display(data_sales_profit[data_sales_profit['Description']=='?'].loc[:,'StockCode'])
display(data_sales_profit[data_sales_profit['Description']=='?'].loc[:,'StockCode'].values)
# Out:
# 220843    85123A
# 38261      21479
# 282882     22171
# 115807     84988
# 421093    72803A
# 323315     23135
# Name: StockCode, dtype: object
# array(['85123A', '21479', '22171', '84988', '72803A', '23135'],
#       dtype=object)

# %%
for stockcode in np.unique(data_sales_profit[data_sales_profit['Description']=='?']['StockCode'].values):
    print(data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()[0])
# Out:
# WHITE SKULL HOT WATER BOTTLE
# 3 HOOK PHOTO SHELF ANTIQUE WHITE
# SMALL ZINC HEART WALL ORGANISER
# ROSE SCENT CANDLE JEWELLED DRAWER
# SET OF 72 PINK HEART PAPER DOILIES
# WHITE HANGING HEART T-LIGHT HOLDER

# %%
for stockcode in np.unique(data_sales_profit[data_sales_profit['Description']=='nan']['StockCode'].values):
    # if (data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()[0] != 'nan'):
    #     print(data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()[0])
    if 'nan' in (data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()):
        if(len(data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique())>1):
            if (data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()[0])=='nan':
                print(data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()[1])
            else:
                print(data_sales_profit[data_sales_profit['StockCode']==stockcode]['Description'].unique()[0])
        else:
            print("No description for stock code = ", stockcode)
# Out:
# INFLATABLE POLITICAL GLOBE
# GROOVY CACTUS INFLATABLE
# FAN BLACK FRAME
# BLUE POLKADOT GARDEN PARASOL
# FAIRY CAKE DESIGN UMBRELLA
# MEDIUM CHINESE STYLE SCISSOR
# MINI HIGHLIGHTER PENS
# TEATIME PEN CASE & PENS
# TEATIME GEL PENS ASST
# THE KING GIFT BAG
# PINK STRAWBERRY HANDBAG
# PINK HEART RED HANDBAG
# BLUE HOLE PUNCH
# ORIGAMI VANILLA INCENSE CONES
# LAVENDER INCENSE IN TIN
# ASS COL LARGE SAND FROG P'WEIGHT
# PORCELAIN BUTTERFLY OIL BURNER
# TROPICAL HOLIDAY PURSE
# STRAWBERRY DREAM CHILDS UMBRELLA
# PINK PADDED MOBILE
# JUMBO BAG OWLS
# PARTY FOOD SHOPPER BAG
# POSY CANDY BAG
# SILVER MINI TAPE MEASURE
# KENSINGTON COFFEE SET
# GARDEN PATH POCKET BOOK
# GREEN FERN NOTEBOOK
# GARDEN PATH NOTEBOOK
# CLEAR MILKSHAKE GLASS
# LARGE PINK GLASS SUNDAE DISH
# GOLDIE LOOKING MIRROR
# No description for stock code =  20849
# ZINC HEART LATTICE TRAY OVAL
# SET/9 CHRISTMAS T-LIGHTS SCENTED
# BOX OF 9 PEBBLE CANDLES
# FROG CANDLE
# No description for stock code =  20950
# PORCELAIN T-LIGHT HOLDERS ASSORTED
# POLYESTER FILLER PAD 60x40cm
# SANDWICH BATH SPONGE
# 12 PENCIL SMALL TUBE WOODLAND
# 12 PENCILS SMALL TUBE RED RETROSPOT
# 12 PENCILS TALL TUBE POSY
# ETCHED GLASS STAR TREE DECORATION
# NINJA RABBIT PINK
# JUMBO BAG CHARLIE AND LOLA TOYS
# NURSE'S BAG SOFT TOY
# VINTAGE RED TEATIME MUG
# VINTAGE BILLBOARD TEA MUG
# VINTAGE BILLBOARD DRINK ME MUG
# SET/6 POSIES PAPER PLATES
# CHRISTMAS TOILET ROLL
# No description for stock code =  21134
# ANTIQUE GLASS HEART DECORATION
# ANTIQUE GLASS PLACE SETTING
# JINGLE BELLS TREE DECORATION
# POTTERING IN THE SHED METAL SIGN
# PLEASE ONE PERSON METAL SIGN
# WHITE DOVE HONEYCOMB PAPER GARLAND
# PINK HEARTS PAPER GARLAND
# BLUE POLKADOT PLATE
# VICTORIAN SEWING BOX MEDIUM
# VICTORIAN SEWING BOX LARGE
# ANTIQUE CREAM CUTLERY SHELF
# SALLE DE BAIN HOOK
# ZINC TOP  2 DOOR WOODEN SHELF
# PAPER CHAIN KIT EMPIRE
# PAPER BUNTING WHITE LACE
# PAPER BUNTING COLOURED LACE
# HOT WATER BOTTLE TEA AND SYMPATHY
# NOEL WOODEN BLOCK LETTERS
# UNION JACK HOT WATER BOTTLE
# RETROSPOT TEA SET CERAMIC 11 PC
# CHRISTMAS CRAFT HEART STOCKING
# FELTCRAFT 6 FLOWER FRIENDS
# ANGEL DECORATION WITH LACE PADDED
# ORGANISER WOOD ANTIQUE WHITE
# 3 HOOK PHOTO SHELF ANTIQUE WHITE
# METAL 4 HOOK HANGER FRENCH CHATEAU
# RETROSPOT LAMP
# BLACK DINER WALL CLOCK
# MILK PAN PINK POLKADOT
# CAKE STAND LACE WHITE
# 5 HOOK HANGER MAGIC TOADSTOOL
# FELTCRAFT DOLL MARIA
# PINK POLKADOT KIDS BAG
# LUNCH BOX WITH CUTLERY FAIRY CAKES
# GROW YOUR OWN PLANT IN A CAN
# SILK PURSE BABUSHKA RED
# CAST IRON HOOK GARDEN TROWEL
# HEART OF WICKER SMALL
# HEART OF WICKER LARGE
# PICNIC BASKET WICKER LARGE
# PICNIC BASKET WICKER SMALL
# FELTCRAFT CUSHION OWL
# FELTCRAFT CUSHION RABBIT
# WOODEN TREE CHRISTMAS SCANDINAVIAN
# CARDHOLDER GINGHAM CHRISTMAS TREE
# WOODEN SKITTLES GARDEN SET
# MINT KITCHEN SCALES
# HAND WARMER RED POLKA DOT
# DOORMAT CHRISTMAS VILLAGE
# DOORMAT PEACE ON EARTH BLUE
# DOORMAT MERRY CHRISTMAS RED
# WICKER WREATH LARGE
# GUMBALL MONOCHROME COAT RACK
# SET OF 3 CAKE TINS PANTRY DESIGN
# SET OF 6 SPICE TINS PANTRY DESIGN
# ALARM CLOCK BAKELIKE GREEN
# ALARM CLOCK BAKELIKE ORANGE
# SET OF 6 RIBBONS VINTAGE CHRISTMAS
# RUSTIC WOODEN CABINET, GLASS DOORS
# GLASS BELL JAR LARGE
# SET 3 WICKER OVAL BASKETS W LIDS
# SET OF 6 T-LIGHTS SNOWMEN
# PACK 3 BOXES CHRISTMAS PANNETONE
# RUSTIC  SEVENTEEN DRAWER SIDEBOARD
# SWEETHEART WIRE WALL TIDY
# UTILTY CABINET WITH HOOKS
# HALL CABINET WITH 3 DRAWERS
# HOT WATER BOTTLE BABUSHKA
# 3 TIER CAKE TIN RED AND CREAM
# BREAD BIN DINER STYLE IVORY
# HAND WARMER OWL DESIGN
# HAND WARMER SCOTTY DOG DESIGN
# HAND WARMER BIRD DESIGN
# CHRISTMAS LIGHTS 10 VINTAGE BAUBLES
# WOODEN ADVENT CALENDAR RED
# WRAP CHRISTMAS VILLAGE
# ROSE COTTAGE KEEPSAKE BOX
# SOLDIERS EGG CUP
# RABBIT NIGHT LIGHT
# LARGE ZINC HEART WALL ORGANISER
# SMALL ZINC HEART WALL ORGANISER
# REGENCY MILK JUG PINK
# SET OF 2 CERAMIC CHRISTMAS REINDEER
# DOORMAT VINTAGE LEAVES DESIGN
# DOORMAT KEEP CALM AND COME IN
# SET OF 36 DOILIES PANTRY DESIGN
# CHILDRENS TOY COOKING UTENSIL SET
# SHELF WITH 4 HOOKS HOME SWEET HOME
# HOME SWEET HOME KEY HOLDER
# HEART MIRROR ANTIQUE WHITE
# Next Day Carriage
# WALL ART CLASSIC PUDDINGS
# PACKING CHARGE
# SNACK TRAY I LOVE LONDON
# High Resolution Image
# SET OF 3 PINK FLYING DUCKS
# WOODEN BOX ADVENT CALENDAR
# No description for stock code =  35592T
# PINK/WHITE CHRISTMAS TREE 30CM
# DUSTY PINK CHRISTMAS TREE 60CM
# PINK FLUFFY CHRISTMAS DECORATION
# VINTAGE BEAD PINK JEWEL BOX
# VINTAGE BEAD NOTEBOOK
# ENAMEL BLUE RIM TEA CONTAINER
# ENAMEL BLUE RIM COFFEE CONTAINER
# ACRYLIC JEWEL SNOWFLAKE, PINK
# ACRYLIC HANGING JEWEL,BLUE
# ACRYLIC HANGING JEWEL,PINK
# MULTICOLOUR RABBIT EGG WARMER
# PINK CHICK EGG WARMER + EGG CUP
# PEACH KNITTED HEN
# PINK STOCKING CHRISTMAS DECORATION
# No description for stock code =  35951
# SMALLFOLKART BAUBLE CHRISTMAS DEC
# FOLKART ZINC STAR CHRISTMAS DEC
# FOLKART HEART NAPKIN RINGS
# FOLKART CHRISTMAS TREE T-LIGHT HOLD
# ASSTD MULTICOLOUR CIRCLES MUG
# POLKADOT COFFEE CUP & SAUCER PINK
# RETRO COFFEE MUGS ASSORTED
# ICON MUG REVOLUTIONARY
# YELLOW BREAKFAST CUP AND SAUCER
# BLUE BREAKFAST CUP AND SAUCER
# PINK BREAKFAST CUP AND SAUCER
# FUNKY MONKEY MUG
# PIG MUG IN TWO COLOUR DESIGNS
# HARDMAN MUG 3 ASSORTED
# SET/4 2 TONE EGG SHAPE MIXING BOWLS
# CUBIC MUG FLOCK BLUE ON BROWN
# YELLOW/PINK FLOWER DESIGN BIG MUG
# TEA TIME TEA SET IN GIFT BOX
# NEW ENGLAND MUG W GIFT BOX
# RED DAISY PAPER LAMPSHADE
# M/COLOUR POM-POM CURTAIN
# SUNSET COLOUR CHUNKY KNITTED THROW
# WINE BOTTLE DRESSING DARK BLUE
# SET/6 BEAD COASTERS GAUZE BAG GOLD
# ENGLISH ROSE GARDEN SECATEURS
# TEA TIME TABLE CLOTH
# CONGRATULATIONS BUNTING
# SCOTTIES CHILDRENS APRON
# CAROUSEL PONIES BABY BIB
# DOORMAT MULTICOLOUR STRIPE
# BLUE CHECK BAG W HANDLE 34X20CM
# No description for stock code =  62095B
# WHITE HANGING BEADS CANDLE HOLDER
# COLOUR GLASS. STAR T-LIGHT HOLDER
# IVORY SCULPTED RND CANDLE
# 4 BLUE DINNER CANDLES SILVER FLOCK
# 4 BURGUNDY WINE DINNER CANDLES
# VANILLA SCENT CANDLE JEWELLED BOX
# No description for stock code =  72803B
# No description for stock code =  72814
# SET OF 2 CHRISTMAS DECOUPAGE CANDLE
# CHRISTMAS DECOUPAGE CANDLE
# STRING OF 8 BUTTERFLIES,PINK
# DOLPHIN WINDMILL
# UNION FLAG WINDSOCK
# MOROCCAN TEA GLASS
# TUMBLER, BAROQUE
# RETRO TIN ASHTRAY,REVOLUTIONARY
# RETRO PILL BOX KEY CHAIN,THE KING
# RETRO PILL BOX , REVOLUTIONARY
# ST GEORGE SET OF 10 PARTY LIGHTS
# BLACK CHAMPAGNE GLASS
# BLACK WINE GLASS
# ART LIGHTS,FUNK MONKEY
# CHILLI LIGHTS
# LIGHT PINK FLOCK GLASS CANDLEHOLDER
# BLUE FLOCK GLASS CANDLEHOLDER
# ROUND BLUE CLOCK WITH SUCKER
# WOOD 2 DRAWER CABINET WHITE FINISH
# WOODEN FRAME ANTIQUE WHITE
# HOT BATHS METAL SIGN
# FANNY'S REST STOPMETAL SIGN
# OLD DOC RUSSEL METAL SIGN
# RED WOOLLY HOTTIE WHITE HEART.
# KNITTED UNION FLAG HOT WATER BOTTLE
# HEN HOUSE W CHICK IN NEST
# No description for stock code =  84247C
# PACK/12 XMAS FUN CARD
# FOLK ART GREETING CARD,pack/12
# FAWN AND MUSHROOM GREETING CARD
# ASSTD DESIGN BUBBLE GUM RING
# CHERRY BLOSSOM DECORATIVE FLASK
# S/3 PINK SQUARE PLANTERS ROSES
# ORANGE TV TRAY TABLE
# BIRD ON BRANCH CANVAS SCREEN
# WISE MAN STAR SHAPE EGG PAN
# PURPLE DRESS JEWELLERY STAND
# METAL RABBIT LADDER EASTER
# YELLOW METAL CHICKEN HEART
# BUTTONS AND STRIPES NOTEBOOK
# STRIPES DESIGN MONKEY DOLL
# FAIRY CAKE NOTEBOOK A5 SIZE
# ENGLISH ROSE NOTEBOOK A6 SIZE
# KNITTED RABBIT DOLL
# CROCHET BEAR RED/BLUE  KEYRING
# PINK/WHITE RIBBED MELAMINE JUG
# LARGE TORTILLA DESIGN RED BOWL
# SMALL LICORICE DES PINK BOWL
# SMALL CHOCOLATES PINK BOWL
# MIXED NUTS LIGHT GREEN BOWL
# No description for stock code =  84611B
# WHITE STITCHED WALL CLOCK
# PINK STITCHED WALL CLOCK
# GRASS HOPPER WOODEN WALL CLOCK
# No description for stock code =  84670
# FROG KING WATERING CAN
# BEACH HUT KEY CABINET
# BEACH HUT MIRROR
# BEACH HUT DESIGN BLACKBOARD
# S/2 BEACH HUT TREASURE CHESTS
# PACK 20 DOLLY PEGS
# PINK OVAL JEWELLED MIRROR
# CITRUS GARLAND FELT FLOWERS
# PINK EASTER HENS+FLOWER
# SMALL HANGING GLASS+ZINC LANTERN
# RED ROSE AND LACE C/COVER
# ENCHANTED BIRD PLANT CAGE
# OCEAN STRIPE HAMMOCK
# BLUE SAVANNAH PICNIC HAMPER FOR 2
# WHITE ANEMONE ARTIFICIAL FLOWER
# DANISH ROSE FOLDING CHAIR
# SWEETHEART CARRY-ALL BASKET
# FLORAL BATHROOM SET
# HOT BATHS SOAP HOLDER
# BLUE MONTE CARLO HANDBAG
# PINK MONTE CARLO HANDBAG
# PINK RIVIERA HANDBAG
# FUNKY FLOWER PICNIC BAG FOR 4
# PINK B'FLY C/COVER W BOBBLES
# PINK ROSE WASHBAG
# WHITE HAND TOWEL WITH BUTTERFLY
# CREAM AND PINK FLOWERS PONY
# PSYCHEDELIC WALL THERMOMETER
# SET OF 6 KASHMIR FOLKART BAUBLES
# MIRROR LOVE BIRD T-LIGHT HOLDER
# SET OF 16 VINTAGE IVORY CUTLERY
# No description for stock code =  84971L
# WIRE FLOWER T-LIGHT HOLDER
# 75 GREEN FAIRY CAKE CASES
# 60 GOLD AND SILVER FAIRY CAKE CASES
# SET OF 3 CONEY ISLAND OVAL BOXES
# SET OF 6 VINTAGE NOTELETS KIT
# ENVELOPE 50 BLOSSOM IMAGES
# No description for stock code =  85018C
# PINK HEART SHAPE PHOTO FRAME
# FRENCH CHATEAU LARGE PLATTER
# FRENCH CHATEAU LARGE FRUIT BOWL
# FRENCH CHATEAU SMALL FRUITBOWL
# YULETIDE IMAGES GIFT WRAP SET
# No description for stock code =  85044
# GREEN CHRISTMAS TREE STRING 20LIGHT
# LUSH GREENS RIBBONS
# BRIGHT BLUES RIBBONS
# HOLLY TOP CHRISTMAS STOCKING
# CANDY SPOT HEART DECORATION
# HILDA CANDY SPOT RABBIT
# JUMBO BAG STRAWBERRY
# CUT GLASS HEXAGON T-LIGHT HOLDER
# CUT GLASS T-LIGHT HOLDER OCTAGON
# SMALL ROUND CUT GLASS CANDLESTICK
# YELLOW DRAGONFLY HELICOPTER
# BLUE DRAGONFLY HELICOPTER
# JARDIN ETCHED GLASS FRUITBOWL
# JARDIN ETCHED GLASS LARGE BELL JAR
# JARDIN ETCHED GLASS SMALL BELL JAR
# LADIES & GENTLEMEN METAL SIGN
# HAND OVER THE CHOCOLATE   SIGN
# SET/6 IVORY BIRD T-LIGHT CANDLES
# CACTI T-LIGHT CANDLES
# PINK HORSE SOCK PUPPET
# FROG SOCK PUPPET
# SET OF 12 MINI BUNNIES IN A BUCKET
# BUNNY EGG BOX
# CREAM FELT EASTER EGG BASKET
# S/4 GROOVY CAT MAGNETS
# MINI  ZINC GARDEN DECORATIONS
# TUB 24 PINK FLOWER PEGS
# ASSORTED CHEESE FRIDGE MAGNETS
# No description for stock code =  85226A
# SET OF 3 BABUSHKA STACKING TINS
# SET/3 DECOUPAGE STACKING TINS
# FLOWER BURST SILVER RING CRYSTAL
# JADE GREEN ENAMEL HAIR COMB
# MIDNIGHT BLUE GLASS/SILVER BRACELET
# No description for stock code =  90042B
# FRESHWATER PEARL BRACELET IVORY
# DIAMANTE BOW BROOCH RED COLOUR
# PINK CRYSTAL GUITAR PHONE CHARM
# PURPLE FRANGIPANI HAIRCLIP
# PINK DOLLY HAIR CLIPS
# BEADED LOVE HEART JEWELLERY SET
# BLUE SWEETHEART BRACELET
# GREEN ENAMEL+GLASS HAIR COMB
# PINK ENAMEL+GLASS HAIR COMB

# %%
for invoice in (data_sales_nonProfit[data_sales_nonProfit['InvoiceNo'].str.startswith('C')==False]['InvoiceNo'].values):
    if 'nan' in (data_sales_nonProfit[data_sales_nonProfit['InvoiceNo']==invoice]['Description'].values):
        temp_code=data_sales_nonProfit[data_sales_nonProfit['InvoiceNo']==invoice]['StockCode'].values
        temp_code=temp_code[0]
        if(len(data_sales_profit[data_sales_profit['StockCode']==temp_code]['Description'].unique())>1):
            if (data_sales_profit[data_sales_profit['StockCode']==temp_code]['Description'].unique()[0]=='nan'):
                print(data_sales_profit[data_sales_profit['StockCode']==temp_code]['Description'].unique()[1])
            else:
                print(data_sales_profit[data_sales_profit['StockCode']==temp_code]['Description'].unique()[0])
        else:
            print("No description for stock code = ", temp_code)
# Out:
# No description for stock code =  84406B
# RED WOOLLY HOTTIE WHITE HEART.
# RED WOOLLY HOTTIE WHITE HEART.
# No description for stock code =  22633
# HAND WARMER RED POLKA DOT
# RECIPE BOX WITH METAL HEART
# ALARM CLOCK BAKELIKE GREEN
# INFLATABLE POLITICAL GLOBE
# WOOD 2 DRAWER CABINET WHITE FINISH
# WOODEN FRAME ANTIQUE WHITE
# WOODEN FRAME ANTIQUE WHITE
# HOT WATER BOTTLE TEA AND SYMPATHY
# HOT WATER BOTTLE TEA AND SYMPATHY
# HOT WATER BOTTLE TEA AND SYMPATHY
# JUMBO BAG CHARLIE AND LOLA TOYS
# JUMBO BAG CHARLIE AND LOLA TOYS
# RETROSPOT TEA SET CERAMIC 11 PC
# No description for stock code =  84854
# No description for stock code =  82567
# No description for stock code =  21169
# GIN + TONIC DIET METAL SIGN
# PINK BREAKFAST CUP AND SAUCER
# GUMBALL MONOCHROME COAT RACK
# No description for stock code =  22926
# 3 TIER CAKE TIN RED AND CREAM
# No description for stock code =  35004C
# No description for stock code =  35004C
# HANGING MEDINA LANTERN SMALL
# HEART OF WICKER SMALL
# HEART OF WICKER LARGE
# ORGANISER WOOD ANTIQUE WHITE
# ORGANISER WOOD ANTIQUE WHITE
# No description for stock code =  84880
# No description for stock code =  21363
# 5 HOOK HANGER MAGIC TOADSTOOL
# 5 HOOK HANGER MAGIC TOADSTOOL
# No description for stock code =  22192
# No description for stock code =  22198
# No description for stock code =  22198
# No description for stock code =  21891
# RUSTIC  SEVENTEEN DRAWER SIDEBOARD
# RETROSPOT LAMP
# HAND WARMER SCOTTY DOG DESIGN
# HAND WARMER OWL DESIGN
# HAND OVER THE CHOCOLATE   SIGN
# HAND WARMER BIRD DESIGN
# SILK PURSE BABUSHKA RED
# SILK PURSE BABUSHKA RED
# No description for stock code =  20820
# No description for stock code =  21907
# SANDWICH BATH SPONGE
# SANDWICH BATH SPONGE
# SANDWICH BATH SPONGE
# No description for stock code =  21743
# COSY HOUR GIANT TUBE MATCHES
# GUMBALL COAT RACK
# No description for stock code =  84625C
# BREAD BIN DINER STYLE PINK
# TEA TIME TABLE CLOTH
# HOT WATER BOTTLE BABUSHKA
# HOT WATER BOTTLE BABUSHKA
# BRIGHT BLUES RIBBONS
# BRIGHT BLUES RIBBONS
# MAGIC DRAWING SLATE BAKE A CAKE
# No description for stock code =  21210
# SET 12 LAVENDER  BOTANICAL T-LIGHTS
# No description for stock code =  20669
# JUMBO BAG OWLS
# No description for stock code =  21116
# JUMBO BAG STRAWBERRY
# BLUE POLKADOT PLATE
# COSY SLIPPER SHOES SMALL  RED
# No description for stock code =  21448
# FELTCRAFT CUSHION RABBIT
# SOLDIERS EGG CUP
# SOLDIERS EGG CUP
# No description for stock code =  35591T
# No description for stock code =  22775
# No description for stock code =  84678
# No description for stock code =  22480
# GREEN FERN NOTEBOOK
# GREEN FERN NOTEBOOK
# No description for stock code =  20773
# No description for stock code =  20773
# HANGING GLASS ETCHED TEALIGHT
# KINGS CHOICE GIANT TUBE MATCHES
# No description for stock code =  84754
# BLUE GIANT GARDEN THERMOMETER
# No description for stock code =  21259
# BLUE SWEETHEART BRACELET
# No description for stock code =  21814
# No description for stock code =  48173C
# CHRISTMAS DECOUPAGE CANDLE
# CHRISTMAS DECOUPAGE CANDLE
# No description for stock code =  21137
# No description for stock code =  20977
# No description for stock code =  20977
# VINTAGE UNION JACK BUNTING
# PAPER BUNTING WHITE LACE
# PAPER BUNTING WHITE LACE
# No description for stock code =  21895
# PINK HEARTS PAPER GARLAND
# No description for stock code =  21894
# No description for stock code =  22712
# No description for stock code =  22024
# RED WHITE SCARF  HOT WATER BOTTLE
# No description for stock code =  22784
# No description for stock code =  22588
# No description for stock code =  21486
# WHITE CHRISTMAS GARLAND STARS TREES
# SMALL LICORICE DES PINK BOWL
# PICNIC BASKET WICKER LARGE
# No description for stock code =  22854
# CHRISTMAS TOILET ROLL
# No description for stock code =  84563A
# HEADS AND TAILS SPORTING FUN
# 12 PENCIL SMALL TUBE WOODLAND
# No description for stock code =  15044B
# METAL 4 HOOK HANGER FRENCH CHATEAU
# METAL 4 HOOK HANGER FRENCH CHATEAU
# No description for stock code =  22625
# No description for stock code =  22244
# No description for stock code =  84569B
# No description for stock code =  84569B
# No description for stock code =  22454
# No description for stock code =  22453
# No description for stock code =  22445
# No description for stock code =  22164
# MINT KITCHEN SCALES
# No description for stock code =  21038
# No description for stock code =  21179
# VINTAGE GLASS COFFEE CADDY
# GLASS  BEURRE DISH
# BLACK DINER WALL CLOCK
# BLACK DINER WALL CLOCK
# DOORMAT PEACE ON EARTH BLUE
# GROW YOUR OWN PLANT IN A CAN
# No description for stock code =  22966
# No description for stock code =  22966
# No description for stock code =  21870
# No description for stock code =  22665
# No description for stock code =  22567
# POLKADOT PEN
# No description for stock code =  22791
# PAPER BUNTING COLOURED LACE
# ANTIQUE GLASS HEART DECORATION
# ANTIQUE GLASS HEART DECORATION
# SET OF 6 KASHMIR FOLKART BAUBLES
# No description for stock code =  85067
# No description for stock code =  85067
# RED GINGHAM ROSE JEWELLERY BOX
# RED GINGHAM ROSE JEWELLERY BOX
# BLUE DRAGONFLY HELICOPTER
# BLUE DRAGONFLY HELICOPTER
# CHRISTMAS TREE DECORATION WITH BELL
